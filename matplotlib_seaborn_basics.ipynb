# %%
import pandas as pd

df_sales = pd.read_excel("linechart.xlsx")
df_sales
# Out:
#    Quarter  Fridge  Dishwasher  Washing Machine
# 0  Q1 2022    12.5         8.0              9.2
# 1  Q2 2022    11.0         7.5              8.5
# 2  Q3 2022    13.2         9.0              7.5
# 3  Q4 2022    16.4        11.0              7.6
# 4  Q1 2023    13.8         9.5              6.8
# 5  Q2 2023    14.0         8.0              6.0

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(12,4))
plt.plot(df_sales["Quarter"], df_sales["Fridge"], color='red', label="Fridge")
plt.plot(df_sales["Quarter"], df_sales["Dishwasher"], color='blue', label="Dishwasher")
plt.plot(df_sales["Quarter"], df_sales["Washing Machine"], color='green', label="Washing Machine")

plt.title("Product Sales")
plt.ylabel("Revenue (Million $)")
plt.xlabel("Financial Quater")

plt.legend()

plt.show()

# %%
#Pie chart
total_sales = df_sales[["Fridge", "Dishwasher", "Washing Machine"]].sum()
total_sales
# Out:
# Fridge             80.9
# Dishwasher         53.0
# Washing Machine    45.6
# dtype: float64

# %%
total_sales.index
# Out:
# Index(['Fridge', 'Dishwasher', 'Washing Machine'], dtype='object')

# %%
plt.pie(total_sales, labels=total_sales.index, autopct="%1.2f%%", explode=(0.1,0.2,0), shadow=True)

plt.show()

# %%
# Product wise revenue in a bar chart

df_sales.plot(kind="bar", x="Quarter")

plt.xticks(rotation=45) # rotate x label

plt.show()

# %%
df_sales_2 = df_sales.set_index("Quarter")

# %%
df_sales_2
# Out:
#          Fridge  Dishwasher  Washing Machine
# Quarter
# Q1 2022    12.5         8.0              9.2
# Q2 2022    11.0         7.5              8.5
# Q3 2022    13.2         9.0              7.5
# Q4 2022    16.4        11.0              7.6
# Q1 2023    13.8         9.5              6.8
# Q2 2023    14.0         8.0              6.0

# %%
df_sales_2.loc["Q1 2022"]
# Out:
# Fridge             12.5
# Dishwasher          8.0
# Washing Machine     9.2
# Name: Q1 2022, dtype: float64

# %%
# Product wise revenue in a bar chart 2

df_sales_2.plot(kind="bar") # no need to supply x now

plt.xticks(rotation=45) # rotate x label

plt.show()

# %%
# Histograms

# %%
df_score = pd.read_excel("histograms.xlsx")
df_score.head(5)
# Out:
#        Name  Exam_Score
# 0     Aarav          45
# 1   Michael          71
# 2     Bilal          59
# 3  Priyanka          92
# 4    Sophia           0

# %%
plt.hist(df_score["Exam_Score"])
plt.show()

# %%
# Ploting Histogram with Seaborn for better visualization

import seaborn as sns

sns.histplot(data=df_score, x="Exam_Score", kde=True) # kurnel density estimator

plt.xlabel("Score")
plt.ylabel("Count")
plt.title("Exam Scores")
plt.show()

# %%
# Scatter Plot

# %%
df = pd.read_excel("scatter_plot.xlsx")
df
# Out:
#    area_square_ft  price
# 0             650     55
# 1             800     91
# 2             950     96
# 3            1100    122
# 4             500     34
# 5            1200    120
# 6             700     95
# 7             850    110
# 8            1000    115
# 9            1150     41

# %%
sns.scatterplot(data=df, x="area_square_ft", y="price")
plt.show()
